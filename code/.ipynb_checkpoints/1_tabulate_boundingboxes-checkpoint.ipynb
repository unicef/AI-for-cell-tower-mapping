# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import json
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1. Visualize cell tower images and bounding boxes

# %% [markdown]
# ### 1.1 Define paths

# %%
image_folder = "/content/drive/MyDrive/UNICEF & NYU Giga initiative - data sharing/data/interim_images/restored_imgs"
bb_file = "/content/drive/MyDrive/UNICEF & NYU Giga initiative - data sharing/data/processed_bounding_boxes/labelbox_alejandro.json"

# %% [markdown]
# ### 1.2 Visualize cell tower images

# %%
# %pylab inline
img = mpimg.imread(os.path.join(image_folder, '9996110239.png'))
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### 1.3 Bounding boxes

# %%
bounding_boxes = json.load(open(bb_file))

# %%
n = len(bounding_boxes)
tabular_bb = pd.DataFrame()
for i in range(n):
  for j in range(len(bounding_boxes[i]['Label']['objects'])):
    current_bb = bounding_boxes[i]['Label']['objects'][j]['polygon']
    min_x = min([c['x'] for c in current_bb])
    max_x = max([c['x'] for c in current_bb])
    min_y = min([c['y'] for c in current_bb])
    max_y = max([c['y'] for c in current_bb])
    current_df = pd.DataFrame({'id': [bounding_boxes[i]['External ID']],
                               'min_x': [min_x],
                               'min_y': [min_y],
                               'max_x': [max_x],
                               'max_y': [max_y]
                            })
    tabular_bb = pd.concat([tabular_bb, current_df])

# %%
bounding_boxes
# Out:
# [{'ID': 'cl9ddwo2d2hex072q4p9x9ah9',
#   'DataRow ID': 'cl967lkwy003q076ofd2o0oez',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F6cb49977-8292-57bc-8e1f-9cd643cce533-1550575138.png?Expires=1667354655654&KeyName=labelbox-assets-key-3&Signature=vBdR13_PBu6dlPaX1IpDfsrhK7o',
#   'Label': {'objects': [{'featureId': 'cl9ddxzg60000356leva9zfhp',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1704.465, 'y': 872.052},
#       {'x': 1951.105, 'y': 2166.916},
#       {'x': 2171.32, 'y': 2210.959},
#       {'x': 2215.363, 'y': 2034.787}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9ddxzg60000356leva9zfhp?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:06:21.000Z',
#   'Updated At': '2022-10-17T23:06:22.000Z',
#   'Seconds to Label': 17.685,
#   'Seconds to Review': 0,
#   'Seconds to Create': 17.685,
#   'External ID': '1550575138.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9ddwo2d2hex072q4p9x9ah9',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9ddxud01flz07163muv4uck',
#   'DataRow ID': 'cl967lkwy003u076o2a2p7dbh',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F089d2cd0-b4b5-15c6-e5bb-b2d0658a1aed-1608952103.png?Expires=1667354655659&KeyName=labelbox-assets-key-3&Signature=nkag-Z03eddmOFQFKPVYg4zn4mk',
#   'Label': {'objects': [{'featureId': 'cl9ddyakv0001356lbtvexjgs',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1545.91, 'y': 466.856},
#       {'x': 1871.828, 'y': 1885.041},
#       {'x': 1915.871, 'y': 2633.772},
#       {'x': 2224.172, 'y': 2087.639},
#       {'x': 2109.66, 'y': 1832.189}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9ddyakv0001356lbtvexjgs?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:06:35.000Z',
#   'Updated At': '2022-10-17T23:06:35.000Z',
#   'Seconds to Label': 14.128,
#   'Seconds to Review': 0,
#   'Seconds to Create': 14.128,
#   'External ID': '1608952103.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9ddxud01flz07163muv4uck',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9ddyaha2jc807125k7igjow',
#   'DataRow ID': 'cl967lkwy003y076o0y9hgmj1',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2Fa3f6b55e-b86c-c2d7-079a-d1c37d459ea6-1668498831.png?Expires=1667354655660&KeyName=labelbox-assets-key-3&Signature=DfM9IeiABBSzub0_g8tr1MN-UqY',
#   'Label': {'objects': [{'featureId': 'cl9ddymz20002356l3vikw2cy',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1528.292, 'y': 1101.075},
#       {'x': 1880.637, 'y': 2070.022},
#       {'x': 2021.574, 'y': 2202.151},
#       {'x': 2382.727, 'y': 2149.299},
#       {'x': 2329.875, 'y': 2017.17}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9ddymz20002356l3vikw2cy?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:06:55.000Z',
#   'Updated At': '2022-10-17T23:06:55.000Z',
#   'Seconds to Label': 15.458,
#   'Seconds to Review': 0,
#   'Seconds to Create': 15.458,
#   'External ID': '1668498831.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9ddyaha2jc807125k7igjow',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9ddykof2je4071216fe4ocr',
#   'DataRow ID': 'cl967lkwy0042076o2e7j0apu',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F0e28887e-6842-1ba7-66ff-6e6b2d62fbe7-1670739886.png?Expires=1667354655660&KeyName=labelbox-assets-key-3&Signature=StvqLbBEA6_p0O0rSZVCX7CIgyE',
#   'Label': {'objects': [{'featureId': 'cl9ddz0eg0003356lwsg247sx',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1880.637, 'y': 1735.295},
#       {'x': 2144.895, 'y': 2184.533},
#       {'x': 2338.684, 'y': 1920.275}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9ddz0eg0003356lwsg247sx?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:07:06.000Z',
#   'Updated At': '2022-10-17T23:07:06.000Z',
#   'Seconds to Label': 10.01,
#   'Seconds to Review': 0,
#   'Seconds to Create': 10.01,
#   'External ID': '1670739886.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9ddykof2je4071216fe4ocr',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9ddyzvj2hx8072q5x2edzbo',
#   'DataRow ID': 'cl967lkwy0046076ogh4y7nsg',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F6c54d766-ed0c-a75b-4742-95fe0606a003-1670739890.png?Expires=1667354655661&KeyName=labelbox-assets-key-3&Signature=-uaiqOWAjFDVB0A3nWv6meGHFZI',
#   'Label': {'objects': [{'featureId': 'cl9de1st60000356lj9533vig',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 2171.32, 'y': 1981.935},
#       {'x': 2462.004, 'y': 2175.725},
#       {'x': 3078.606, 'y': 1312.482},
#       {'x': 2831.966, 'y': 1197.97}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de1st60000356lj9533vig?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'},
#     {'featureId': 'cl9de1zdj0001356l3luc0p1m',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 2920.052, 'y': 2395.94},
#       {'x': 3237.161, 'y': 2651.389},
#       {'x': 3598.314, 'y': 1849.806},
#       {'x': 3395.716, 'y': 1752.912}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de1zdj0001356l3luc0p1m?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:09:24.000Z',
#   'Updated At': '2022-10-17T23:09:24.000Z',
#   'Seconds to Label': 29.846,
#   'Seconds to Review': 0,
#   'Seconds to Create': 29.846,
#   'External ID': '1670739890.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9ddyzvj2hx8072q5x2edzbo',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9ddz98c1z2x070k2ezag28f',
#   'DataRow ID': 'cl967lkwy004a076ofgobe9ea',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2Fdd9674d6-d96c-104c-f4c5-32dd1b6fed90-1992843368.png?Expires=1667354655661&KeyName=labelbox-assets-key-3&Signature=p1pU--v2XQePPu1s2xE1qMMyMsg',
#   'Label': {'objects': [{'featureId': 'cl9de25cx0002356l67gry6lg',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1704.465, 'y': 1118.692},
#       {'x': 1889.445, 'y': 1911.467},
#       {'x': 1880.637, 'y': 2281.428},
#       {'x': 2294.641, 'y': 2202.151},
#       {'x': 2277.024, 'y': 1858.615},
#       {'x': 2074.426, 'y': 1805.763}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de25cx0002356l67gry6lg?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:09:34.000Z',
#   'Updated At': '2022-10-17T23:09:34.000Z',
#   'Seconds to Label': 9.263,
#   'Seconds to Review': 0,
#   'Seconds to Create': 9.263,
#   'External ID': '1992843368.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9ddz98c1z2x070k2ezag28f',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de287q1h7i0713bym35yt6',
#   'DataRow ID': 'cl967lkwz004e076o4smteyyt',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2Ff2be6afe-8b3b-6596-81f0-213366d86078-1994461555.png?Expires=1667354655661&KeyName=labelbox-assets-key-3&Signature=Jw0jpRrWhKXWZ3peEJViw-2Y4fw',
#   'Label': {'objects': [{'featureId': 'cl9de2daa0003356lh28ntjg5',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1598.761, 'y': 1788.146},
#       {'x': 1528.292, 'y': 2580.92},
#       {'x': 2321.067, 'y': 2686.624},
#       {'x': 2409.153, 'y': 1885.041},
#       {'x': 2303.449, 'y': 1700.06}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de2daa0003356lh28ntjg5?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:09:44.000Z',
#   'Updated At': '2022-10-17T23:09:44.000Z',
#   'Seconds to Label': 8.952,
#   'Seconds to Review': 0,
#   'Seconds to Create': 8.952,
#   'External ID': '1994461555.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de287q1h7i0713bym35yt6',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de2exf2hfb071b5yuy9kre',
#   'DataRow ID': 'cl967lkwz004i076oboohdxda',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2Fb7f514c3-0da8-be5a-a573-bb584ed4a6a5-1994461561.png?Expires=1667354655662&KeyName=labelbox-assets-key-3&Signature=vfIPzVXVn9XeuoY3Rb2gIyLl40Y',
#   'Label': {'objects': [{'featureId': 'cl9de2li00004356lep3hy2tu',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1827.785, 'y': 1594.357},
#       {'x': 1915.871, 'y': 2008.361},
#       {'x': 2039.191, 'y': 2299.045},
#       {'x': 2567.708, 'y': 2043.596},
#       {'x': 2532.473, 'y': 1849.806}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de2li00004356lep3hy2tu?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:09:53.000Z',
#   'Updated At': '2022-10-17T23:09:53.000Z',
#   'Seconds to Label': 5.649,
#   'Seconds to Review': 0,
#   'Seconds to Create': 5.649,
#   'External ID': '1994461561.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de2exf2hfb071b5yuy9kre',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de2meh2qpi07yy3a7r8446',
#   'DataRow ID': 'cl967lkwz004m076o780y76lz',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F1fbd2b17-ff50-0915-544a-5765eb5ea0a9-2207437211.png?Expires=1667354655662&KeyName=labelbox-assets-key-3&Signature=2C6St2M5_tYZNs5kEAAox_bUzHM',
#   'Label': {'objects': [{'featureId': 'cl9de2sdl0005356lqbiq6gnh',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1651.613, 'y': 951.329},
#       {'x': 1801.359, 'y': 1330.099},
#       {'x': 2409.153, 'y': 1400.568},
#       {'x': 2391.535, 'y': 1259.63}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de2sdl0005356lqbiq6gnh?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'},
#     {'featureId': 'cl9de2xgs0006356lsbv992rp',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1924.68, 'y': 1964.318},
#       {'x': 2074.426, 'y': 2351.897},
#       {'x': 2743.88, 'y': 2439.983}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de2xgs0006356lsbv992rp?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:10:09.000Z',
#   'Updated At': '2022-10-17T23:10:09.000Z',
#   'Seconds to Label': 17.796,
#   'Seconds to Review': 0,
#   'Seconds to Create': 17.796,
#   'External ID': '2207437211.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de2meh2qpi07yy3a7r8446',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de2tps1hc10713aypzcksk',
#   'DataRow ID': 'cl967lkwz004q076o8b2m29a3',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F5b412325-aed1-3507-c395-3d4e48435c32-2268292194.png?Expires=1667354655662&KeyName=labelbox-assets-key-3&Signature=vYWIEPipvFzUZsOXMLsjPiCRhRk',
#   'Label': {'objects': [{'featureId': 'cl9de34m50007356lzcu56ac3',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1810.168, 'y': 1770.529},
#       {'x': 2083.234, 'y': 2210.959},
#       {'x': 2558.899, 'y': 2052.404}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de34m50007356lzcu56ac3?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:10:17.000Z',
#   'Updated At': '2022-10-17T23:10:18.000Z',
#   'Seconds to Label': 6.91,
#   'Seconds to Review': 0,
#   'Seconds to Create': 6.91,
#   'External ID': '2268292194.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de2tps1hc10713aypzcksk',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de36k72qt807yy33cd6h4p',
#   'DataRow ID': 'cl967lkwz004u076o5ohe8pth',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2Fbb27e7b8-0644-71ab-00bf-224b3d460b9b-2335315442.png?Expires=1667354655663&KeyName=labelbox-assets-key-3&Signature=JhOEjlBOgyLs27QAM-XtVXuC-GM',
#   'Label': {'objects': [{'featureId': 'cl9de3ayo0008356ljn7mwmi5',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 2144.895, 'y': 1823.381},
#       {'x': 2012.766, 'y': 1946.701},
#       {'x': 2162.512, 'y': 2131.682},
#       {'x': 2532.473, 'y': 1981.935}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de3ayo0008356ljn7mwmi5?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:10:26.000Z',
#   'Updated At': '2022-10-17T23:10:26.000Z',
#   'Seconds to Label': 7.427,
#   'Seconds to Review': 0,
#   'Seconds to Create': 7.427,
#   'External ID': '2335315442.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de36k72qt807yy33cd6h4p',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de3dfw2hmm071b8vvo96uc',
#   'DataRow ID': 'cl967lkwz004y076ocl68fxi2',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2Fdef89c29-98fe-228e-ff36-5c218323206c-2339117860.png?Expires=1667354655663&KeyName=labelbox-assets-key-3&Signature=N_xeBZOPsJ8H7LKCu8CFvZ3fHRg',
#   'Label': {'objects': [{'featureId': 'cl9de3h570009356l6znalsgl',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1757.316, 'y': 933.712},
#       {'x': 1810.168, 'y': 2307.854},
#       {'x': 2180.129, 'y': 2237.385}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de3h570009356l6znalsgl?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:10:33.000Z',
#   'Updated At': '2022-10-17T23:10:34.000Z',
#   'Seconds to Label': 6.433,
#   'Seconds to Review': 0,
#   'Seconds to Create': 6.433,
#   'External ID': '2339117860.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de3dfw2hmm071b8vvo96uc',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de3ikz2hnx071b4ef05paj',
#   'DataRow ID': 'cl967lkx10052076o7s0xapmm',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F34126f82-a56f-2617-1fee-953b1e871611-2355671227.png?Expires=1667354655664&KeyName=labelbox-assets-key-3&Signature=xgBn6_Wt1MM5R-2eGnETy3cdi7U',
#   'Label': {'objects': [{'featureId': 'cl9de3msj000a356lz2trd8x1',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1642.804, 'y': 1515.08},
#       {'x': 1598.761, 'y': 1735.295},
#       {'x': 1951.105, 'y': 1858.615},
#       {'x': 1977.531, 'y': 1541.505}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de3msj000a356lz2trd8x1?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:10:40.000Z',
#   'Updated At': '2022-10-17T23:10:40.000Z',
#   'Seconds to Label': 5.092,
#   'Seconds to Review': 0,
#   'Seconds to Create': 5.092,
#   'External ID': '2355671227.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de3ikz2hnx071b4ef05paj',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de3pjk237o07yvf0p12t3d',
#   'DataRow ID': 'cl967lkx10056076o7tukcyn6',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2Fc2f1bf2c-5c2f-aa17-c5f6-3b910c3459c8-2355671293.png?Expires=1667354655664&KeyName=labelbox-assets-key-3&Signature=3DYmGrUyt3KxD1qftp5HT1ZQFa0',
#   'Label': {'objects': [{'featureId': 'cl9de3srb000b356lsmk7cdeh',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1792.551, 'y': 2052.404},
#       {'x': 1951.105, 'y': 2669.006},
#       {'x': 2224.172, 'y': 2263.811},
#       {'x': 2144.895, 'y': 1911.467}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de3srb000b356lsmk7cdeh?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:10:51.000Z',
#   'Updated At': '2022-10-17T23:10:51.000Z',
#   'Seconds to Label': 12.341,
#   'Seconds to Review': 0,
#   'Seconds to Create': 12.341,
#   'External ID': '2355671293.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de3pjk237o07yvf0p12t3d',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de3twv1gwq07162o6r2rr9',
#   'DataRow ID': 'cl967lkx1005a076obmtzh985',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F73efcf71-19c9-dfce-f072-ed040c47bbfd-2355733346.png?Expires=1667354655664&KeyName=labelbox-assets-key-3&Signature=6eb1oRdlmKEuoJVoY9qPQ28vY7o',
#   'Label': {'objects': [{'featureId': 'cl9de405u000c356lbyc1gzde',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1986.34, 'y': 2193.342},
#       {'x': 1951.105, 'y': 2721.858},
#       {'x': 2153.703, 'y': 2651.389},
#       {'x': 2180.129, 'y': 2210.959}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de405u000c356lbyc1gzde?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:10:58.000Z',
#   'Updated At': '2022-10-17T23:10:59.000Z',
#   'Seconds to Label': 7.169,
#   'Seconds to Review': 0,
#   'Seconds to Create': 7.169,
#   'External ID': '2355733346.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de3twv1gwq07162o6r2rr9',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de41y52hru071bcbitfryz',
#   'DataRow ID': 'cl967lkx1005e076o25551345',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F2d4d5b6f-b45d-423f-13c4-e18b63290b71-2419479288.png?Expires=1667354655665&KeyName=labelbox-assets-key-3&Signature=BIMWGLrM_rtvK5X8agIe7OjrpTE',
#   'Label': {'objects': [{'featureId': 'cl9de46h9000d356lqrspwipd',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1854.211, 'y': 1444.611},
#       {'x': 1933.488, 'y': 2140.49},
#       {'x': 2576.516, 'y': 2070.022},
#       {'x': 2180.129, 'y': 1937.892}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de46h9000d356lqrspwipd?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:11:07.000Z',
#   'Updated At': '2022-10-17T23:11:07.000Z',
#   'Seconds to Label': 7.1,
#   'Seconds to Review': 0,
#   'Seconds to Create': 7.1,
#   'External ID': '2419479288.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de41y52hru071bcbitfryz',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de48gp2r1v07yy7tknhqyl',
#   'DataRow ID': 'cl967lkx1005i076o4o3pft31',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F6f4785cd-5f82-0511-c76b-9fbc17d7ab59-2495014064.png?Expires=1667354655665&KeyName=labelbox-assets-key-3&Signature=AmuJmb8hw0UPMXZrDIhgQ29RVXA',
#   'Label': {'objects': [{'featureId': 'cl9de4cdl000e356ls0dxl7ty',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1915.871, 'y': 1849.806},
#       {'x': 2162.512, 'y': 2492.834},
#       {'x': 2488.43, 'y': 2316.662},
#       {'x': 2056.809, 'y': 1770.529}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de4cdl000e356ls0dxl7ty?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:11:14.000Z',
#   'Updated At': '2022-10-17T23:11:14.000Z',
#   'Seconds to Label': 9.347,
#   'Seconds to Review': 0,
#   'Seconds to Create': 9.347,
#   'External ID': '2495014064.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de48gp2r1v07yy7tknhqyl',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de4g3k2hv2071b8qv05urs',
#   'DataRow ID': 'cl967lkx1005m076og9c40st4',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F327da881-4985-2e73-0fa2-eab6af4ad34c-2495014096.png?Expires=1667354655665&KeyName=labelbox-assets-key-3&Signature=5qXuCwDW-IjO2CgwDsSJtXgOXcg',
#   'Label': {'objects': [{'featureId': 'cl9de4ilg000f356lx3hzdulj',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 2039.191, 'y': 1735.295},
#       {'x': 2365.11, 'y': 2263.811},
#       {'x': 2620.559, 'y': 2299.045},
#       {'x': 2761.497, 'y': 2034.787},
#       {'x': 2391.535, 'y': 1770.529}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de4ilg000f356lx3hzdulj?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:11:24.000Z',
#   'Updated At': '2022-10-17T23:11:26.000Z',
#   'Seconds to Label': 10.361,
#   'Seconds to Review': 0,
#   'Seconds to Create': 10.361,
#   'External ID': '2495014096.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de4g3k2hv2071b8qv05urs',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de4k2v2kna07129jieeyfr',
#   'DataRow ID': 'cl967lkx1005q076obhika92l',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2Fa21387e9-e0b5-5f8b-0bc2-5912445848ad-2495014107.png?Expires=1667354655665&KeyName=labelbox-assets-key-3&Signature=FmKV5Uyarb7XvWEEtdcPfnK1w-M',
#   'Label': {'objects': [{'featureId': 'cl9de4rt7000h356low7tqj97',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 2083.234, 'y': 1840.998},
#       {'x': 2444.387, 'y': 2713.049},
#       {'x': 2867.2, 'y': 2950.882},
#       {'x': 2964.095, 'y': 2669.006},
#       {'x': 2567.708, 'y': 2431.174}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de4rt7000h356low7tqj97?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:11:36.000Z',
#   'Updated At': '2022-10-17T23:11:36.000Z',
#   'Seconds to Label': 5.341,
#   'Seconds to Review': 0,
#   'Seconds to Create': 5.341,
#   'External ID': '2495014107.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de4k2v2kna07129jieeyfr',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de4t4b1mxp071724394dd2',
#   'DataRow ID': 'cl967lkx1005u076odj3nc07e',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2Fd22748b2-bd04-fbc0-58ef-a5f2b1654d98-2495014117.png?Expires=1667354655665&KeyName=labelbox-assets-key-3&Signature=lynuOTZRXU56n9oo5X9VCgYq6NA',
#   'Label': {'objects': [{'featureId': 'cl9de4zg5000i356l3cbwirpg',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 3060.989, 'y': 1691.252},
#       {'x': 2990.52, 'y': 1832.189},
#       {'x': 3765.677, 'y': 3162.288},
#       {'x': 4065.17, 'y': 2774.71}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de4zg5000i356l3cbwirpg?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:11:47.000Z',
#   'Updated At': '2022-10-17T23:11:47.000Z',
#   'Seconds to Label': 12.541,
#   'Seconds to Review': 0,
#   'Seconds to Create': 12.541,
#   'External ID': '2495014117.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de4t4b1mxp071724394dd2',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de512z2krd07128c3a3anc',
#   'DataRow ID': 'cl967lkx1005y076oe46l0i5d',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F25b3d3ad-cf0b-6871-c804-2394b2eb0df5-2495014119.png?Expires=1667354655666&KeyName=labelbox-assets-key-3&Signature=5YbRiSQQhj7B5UGwb66r00pwFII',
#   'Label': {'objects': [{'featureId': 'cl9de57re000j356lyuz86m6a',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 2232.981, 'y': 2017.17},
#       {'x': 2426.77, 'y': 1946.701},
#       {'x': 2955.286, 'y': 3012.542},
#       {'x': 2655.794, 'y': 3144.671}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de57re000j356lyuz86m6a?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:11:58.000Z',
#   'Updated At': '2022-10-17T23:11:59.000Z',
#   'Seconds to Label': 9.361,
#   'Seconds to Review': 0,
#   'Seconds to Create': 9.361,
#   'External ID': '2495014119.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de512z2krd07128c3a3anc',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de59lr27sw06z6gmgz2y0s',
#   'DataRow ID': 'cl967lkx10062076o7os06uxv',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F6197a37e-e215-0300-1e31-6d20fc69121a-2627761259.png?Expires=1667354655666&KeyName=labelbox-assets-key-3&Signature=bV7EYVUkYp7-01mjZgwrhKjtv68',
#   'Label': {'objects': [{'featureId': 'cl9de5glo000k356lhgqdtugu',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 2409.153, 'y': 2334.28},
#       {'x': 2823.157, 'y': 3232.757},
#       {'x': 3175.501, 'y': 3426.546},
#       {'x': 3395.716, 'y': 3091.819}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de5glo000k356lhgqdtugu?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:12:08.000Z',
#   'Updated At': '2022-10-17T23:12:08.000Z',
#   'Seconds to Label': 8.059,
#   'Seconds to Review': 0,
#   'Seconds to Create': 8.059,
#   'External ID': '2627761259.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de59lr27sw06z6gmgz2y0s',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de5kuz2rd207yyfxhs4av2',
#   'DataRow ID': 'cl967lkx20066076o9kf20mdl',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F87c3c6be-66d6-833f-3273-1fd21ca60081-2874495332.png?Expires=1667354655666&KeyName=labelbox-assets-key-3&Signature=S3tVlzo4pGAegyGaxOPUBM9x5ZE',
#   'Label': {'objects': [{'featureId': 'cl9de5o6a000l356l2h72087p',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1810.168, 'y': 1594.357},
#       {'x': 1924.68, 'y': 2140.49},
#       {'x': 2321.067, 'y': 2580.92},
#       {'x': 2144.895, 'y': 2070.022}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de5o6a000l356l2h72087p?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:12:19.000Z',
#   'Updated At': '2022-10-17T23:12:20.000Z',
#   'Seconds to Label': 7.966,
#   'Seconds to Review': 0,
#   'Seconds to Create': 7.966,
#   'External ID': '2874495332.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de5kuz2rd207yyfxhs4av2',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de5pn220kw070k1uuf6vy3',
#   'DataRow ID': 'cl967lkx2006a076o01g5c9wb',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2Fa9dacd1e-65c6-c9df-de44-0c328f79794e-2953286812.png?Expires=1667354655666&KeyName=labelbox-assets-key-3&Signature=CAZBUadRJvEb3V4HI-X-KK8iTNQ',
#   'Label': {'objects': [{'featureId': 'cl9de5wgg000m356lbm0j7duu',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1863.019, 'y': 1664.826},
#       {'x': 1898.254, 'y': 2017.17},
#       {'x': 1792.551, 'y': 2334.28},
#       {'x': 2268.215, 'y': 2607.346},
#       {'x': 2162.512, 'y': 2070.022}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de5wgg000m356lbm0j7duu?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:12:28.000Z',
#   'Updated At': '2022-10-17T23:12:28.000Z',
#   'Seconds to Label': 9.034,
#   'Seconds to Review': 0,
#   'Seconds to Create': 9.034,
#   'External ID': '2953286812.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de5pn220kw070k1uuf6vy3',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de5ycn20mv070kgqv7ayxv',
#   'DataRow ID': 'cl967lkx2006e076o46fn3f2i',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2Fd3efeef9-489c-1ab7-7066-cb4e36258a9e-2961809124.png?Expires=1667354655667&KeyName=labelbox-assets-key-3&Signature=X6VDKgf3tZsZWp80tCLMYLvIldU',
#   'Label': {'objects': [{'featureId': 'cl9de63eh000n356llfkgvm6m',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1722.082, 'y': 678.262},
#       {'x': 876.456, 'y': 1576.74},
#       {'x': 3307.63, 'y': 3373.695}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de63eh000n356llfkgvm6m?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:12:38.000Z',
#   'Updated At': '2022-10-17T23:12:38.000Z',
#   'Seconds to Label': 6.099,
#   'Seconds to Review': 0,
#   'Seconds to Create': 6.099,
#   'External ID': '2961809124.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de5ycn20mv070kgqv7ayxv',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de65as20oj070kf03j09r6',
#   'DataRow ID': 'cl967lkx2006i076of2cd8bro',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F1db052c9-8843-599f-0e53-8c16a984ffaa-2961809125.png?Expires=1667354655667&KeyName=labelbox-assets-key-3&Signature=t-ZRKDMpAS3Ca5UU1cDSxbcDq60',
#   'Label': {'objects': [{'featureId': 'cl9de6alv000o356lpuutwjy0',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1818.976, 'y': 1497.462},
#       {'x': 2100.852, 'y': 2175.725},
#       {'x': 2831.966, 'y': 1752.912}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de6alv000o356lpuutwjy0?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:12:44.000Z',
#   'Updated At': '2022-10-17T23:12:45.000Z',
#   'Seconds to Label': 6.273,
#   'Seconds to Review': 0,
#   'Seconds to Create': 6.273,
#   'External ID': '2961809125.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de65as20oj070kf03j09r6',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de6chd20q9070khxdgewly',
#   'DataRow ID': 'cl967lkx2006m076oci6metnh',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2Fead5943f-d467-a53d-0b3e-7c9ccecba8ff-3031178906.png?Expires=1667354655667&KeyName=labelbox-assets-key-3&Signature=Uq-DySRXY5qlZmJ4gPbqv5THyBY',
#   'Label': {'objects': [{'featureId': 'cl9de6fvo000p356lf3ewyj9g',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1845.402, 'y': 1471.037},
#       {'x': 2083.234, 'y': 2246.194},
#       {'x': 2831.966, 'y': 1726.486}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de6fvo000p356lf3ewyj9g?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:12:51.000Z',
#   'Updated At': '2022-10-17T23:12:51.000Z',
#   'Seconds to Label': 7.647,
#   'Seconds to Review': 0,
#   'Seconds to Create': 7.647,
#   'External ID': '3031178906.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de6chd20q9070khxdgewly',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de6hph2rky07yybmi3bmi1',
#   'DataRow ID': 'cl967lkx2006q076o61jg7vza',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F4f7410ff-a448-2546-3259-1be33c8d10b4-3031178907.png?Expires=1667354655667&KeyName=labelbox-assets-key-3&Signature=FyEbakHzc5RriMtwzYbJt0WLNzc',
#   'Label': {'objects': [{'featureId': 'cl9de6ky0000q356l8yb057zh',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1686.847, 'y': 1761.72},
#       {'x': 1995.148, 'y': 2184.533},
#       {'x': 2127.277, 'y': 2008.361}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de6ky0000q356l8yb057zh?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'},
#     {'featureId': 'cl9de6pxj000r356lstifh45o',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 2003.957, 'y': 1752.912},
#       {'x': 2303.449, 'y': 2087.639},
#       {'x': 2444.387, 'y': 1893.849}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9de6pxj000r356lstifh45o?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-17T23:13:04.000Z',
#   'Updated At': '2022-10-17T23:13:04.000Z',
#   'Seconds to Label': 11.969,
#   'Seconds to Review': 0,
#   'Seconds to Create': 11.969,
#   'External ID': '3031178907.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9de6hph2rky07yybmi3bmi1',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9de6mu42l4p0712ainm11ls',
#   'DataRow ID': 'cl967lkx2006u076o5gf102cj',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F4edd5131-f992-198e-913f-ab553de3e1c3-3031178908.png?Expires=1667354655668&KeyName=labelbox-assets-key-3&Signature=Jnq7_uYuUd6JaYyLnP57wtmkNzM',
#   'Label': {'objects': [{'featureId': 'cl9de6v9g000s356levcc1o6g',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1404.972, 'y': 1779.338},
#       {'x': 1730.89, 'y': 2166.916},
#       {'x': 1845.402, 'y': 1981.935}],
# ...
#       {'x': 2109.66, 'y': 2219.768},
#       {'x': 2391.535, 'y': 2017.17},
#       {'x': 2215.363, 'y': 1752.912}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9ezofg7000p356l89nr0h02?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-19T02:02:29.000Z',
#   'Updated At': '2022-10-19T02:02:30.000Z',
#   'Seconds to Label': 6.054,
#   'Seconds to Review': 0,
#   'Seconds to Create': 6.054,
#   'External ID': '9773125377.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9ezobvm0k6c07zyegnka6an',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9ezohhv1qyl08zu1241fqxy',
#   'DataRow ID': 'cl99dubir1wjs084v797qghbg',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2Fb6e26891-b725-b1dd-46eb-abc0ab3e8216-9778415253.png?Expires=1667354656056&KeyName=labelbox-assets-key-3&Signature=K1ozolpkE_fDhTmpgd2pgSh0c6U',
#   'Label': {'objects': [{'featureId': 'cl9ezolax000q356liya4w5cf',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1871.828, 'y': 1708.869},
#       {'x': 1660.422, 'y': 1876.232},
#       {'x': 1951.105, 'y': 2281.428},
#       {'x': 2250.598, 'y': 2043.596},
#       {'x': 2118.469, 'y': 1823.381}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9ezolax000q356liya4w5cf?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-19T02:02:36.000Z',
#   'Updated At': '2022-10-19T02:02:36.000Z',
#   'Seconds to Label': 5.044,
#   'Seconds to Review': 0,
#   'Seconds to Create': 5.044,
#   'External ID': '9778415253.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9ezohhv1qyl08zu1241fqxy',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9ezoozl1qa4070lgdds20pn',
#   'DataRow ID': 'cl99dubir1wjw084vcee06oxd',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F41589089-d78f-84b6-6884-63a15ca4e0e5-9783907129.png?Expires=1667354656056&KeyName=labelbox-assets-key-3&Signature=9MXjNnzYo1mupYn5VxKTHGBcYkE',
#   'Label': {'objects': [{'featureId': 'cl9ezoq90000r356leeyruf5e',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 2056.809, 'y': 1796.955},
#       {'x': 1633.996, 'y': 2228.576},
#       {'x': 1607.57, 'y': 2563.303},
#       {'x': 2162.512, 'y': 2598.538}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9ezoq90000r356leeyruf5e?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-19T02:02:47.000Z',
#   'Updated At': '2022-10-19T02:02:47.000Z',
#   'Seconds to Label': 13.148,
#   'Seconds to Review': 0,
#   'Seconds to Create': 13.148,
#   'External ID': '9783907129.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9ezoozl1qa4070lgdds20pn',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9ezosn21u6h07yrhyu41dsq',
#   'DataRow ID': 'cl99dubir1wk0084v1ql9abmo',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2Fae04f126-1743-fca8-56c0-43cf4f1eb558-9807316520.png?Expires=1667354656057&KeyName=labelbox-assets-key-3&Signature=g2PS36b0zWsGNPFTJBhivkpLKh4',
#   'Label': {'objects': [{'featureId': 'cl9ezoyxg000s356liqstu24g',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1924.68, 'y': 1752.912},
#       {'x': 1968.723, 'y': 2184.533},
#       {'x': 2321.067, 'y': 2325.471},
#       {'x': 2479.622, 'y': 1770.529},
#       {'x': 2180.129, 'y': 1929.084}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9ezoyxg000s356liqstu24g?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-19T02:02:55.000Z',
#   'Updated At': '2022-10-19T02:02:56.000Z',
#   'Seconds to Label': 6.344,
#   'Seconds to Review': 0,
#   'Seconds to Create': 6.344,
#   'External ID': '9807316520.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9ezosn21u6h07yrhyu41dsq',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9ezp0q01u9s07z4f3ymbmb5',
#   'DataRow ID': 'cl99dubir1wk4084vhum66c08',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2Fc91c45b9-6770-2ef8-d575-f8c1b1ae7f10-9807316521.png?Expires=1667354656057&KeyName=labelbox-assets-key-3&Signature=j_U3nNOF72z8oaY_RvvgqyWKNR4',
#   'Label': {'objects': [{'featureId': 'cl9ezp5oi000t356lnfmmhj2r',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1951.105, 'y': 1682.443},
#       {'x': 1818.976, 'y': 2087.639},
#       {'x': 2268.215, 'y': 2122.873}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9ezp5oi000t356lnfmmhj2r?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'},
#     {'featureId': 'cl9ezp93q000u356l871b1up0',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 2761.497, 'y': 1206.778},
#       {'x': 2691.028, 'y': 1541.505},
#       {'x': 3078.606, 'y': 1682.443},
#       {'x': 2990.52, 'y': 1286.056}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9ezp93q000u356l871b1up0?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-19T02:03:08.000Z',
#   'Updated At': '2022-10-19T02:03:08.000Z',
#   'Seconds to Label': 10.151,
#   'Seconds to Review': 0,
#   'Seconds to Create': 10.151,
#   'External ID': '9807316521.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9ezp0q01u9s07z4f3ymbmb5',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9ezp7if05ko070x0emqdmmk',
#   'DataRow ID': 'cl99dubir1wk8084v625e8vs4',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F356a38d3-c5cb-cd54-1682-803ce59e4ed6-9807316522.png?Expires=1667354656057&KeyName=labelbox-assets-key-3&Signature=1SdumI-zKQHBsS4w1Jwk3dvScb8',
#   'Label': {'objects': [{'featureId': 'cl9ezpfdx000v356lcos8r8f2',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1140.714, 'y': 1471.037},
#       {'x': 1070.245, 'y': 1840.998},
#       {'x': 1449.015, 'y': 1858.615}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9ezpfdx000v356lcos8r8f2?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'},
#     {'featureId': 'cl9ezpjdv000w356l1cir4dvk',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 339.131, 'y': 1920.275},
#       {'x': 207.002, 'y': 2263.811},
#       {'x': 541.729, 'y': 2351.897}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9ezpjdv000w356l1cir4dvk?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-19T02:03:19.000Z',
#   'Updated At': '2022-10-19T02:03:19.000Z',
#   'Seconds to Label': 14.764,
#   'Seconds to Review': 0,
#   'Seconds to Create': 14.764,
#   'External ID': '9807316522.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9ezp7if05ko070x0emqdmmk',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9ezph7105ma070x7gnghrcb',
#   'DataRow ID': 'cl99dubir1wkc084vfvzihuy8',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F35686e71-7133-92df-86b7-32289e10b7d4-9932900980.png?Expires=1667354656058&KeyName=labelbox-assets-key-3&Signature=FLBtNULy20f1EDGWuk6W8aRurNo',
#   'Label': {'objects': [{'featureId': 'cl9ezpnjd000x356loscrcw2k',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1105.48, 'y': 2175.725},
#       {'x': 946.925, 'y': 2501.643},
#       {'x': 1325.695, 'y': 2572.112}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9ezpnjd000x356loscrcw2k?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'},
#     {'featureId': 'cl9ezpqrp000y356larz2tdi4',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1986.34, 'y': 1717.677},
#       {'x': 1933.488, 'y': 2017.17},
#       {'x': 2118.469, 'y': 2149.299},
#       {'x': 2215.363, 'y': 2025.978}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9ezpqrp000y356larz2tdi4?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-19T02:03:29.000Z',
#   'Updated At': '2022-10-19T02:03:29.000Z',
#   'Seconds to Label': 6.405,
#   'Seconds to Review': 0,
#   'Seconds to Create': 6.405,
#   'External ID': '9932900980.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9ezph7105ma070x7gnghrcb',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9ezpp9n1yj308xmeyp2750f',
#   'DataRow ID': 'cl99dubir1wkg084v43aqcwkz',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2Fff5eceda-45c6-cbb9-b00d-8d2b7658c45e-9934872453.png?Expires=1667354656058&KeyName=labelbox-assets-key-3&Signature=1nOa-tSpSe0B5ustpx9eOUOtXhQ',
#   'Label': {'objects': [{'featureId': 'cl9ezpvdx000z356loodyuryp',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 2347.492, 'y': 1805.763},
#       {'x': 1915.871, 'y': 1937.892},
#       {'x': 1863.019, 'y': 2175.725},
#       {'x': 2003.957, 'y': 2246.194},
#       {'x': 2197.746, 'y': 2193.342}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9ezpvdx000z356loodyuryp?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-19T02:03:36.000Z',
#   'Updated At': '2022-10-19T02:03:37.000Z',
#   'Seconds to Label': 5.865,
#   'Seconds to Review': 0,
#   'Seconds to Create': 5.865,
#   'External ID': '9934872453.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9ezpp9n1yj308xmeyp2750f',
#   'Has Open Issues': 0,
#   'Skipped': False},
#  {'ID': 'cl9ezpxbh1udj07yr482le60a',
#   'DataRow ID': 'cl99dubir1wkk084vew8r7mg1',
#   'Labeled Data': 'https://storage.labelbox.com/cl961c8k30pxv0817dq7t0veh%2F27c8c844-f1f4-e566-89f0-1b1ec6fc2f0b-10015674326.png?Expires=1667354656059&KeyName=labelbox-assets-key-3&Signature=S8kMs873O0nSWg-w2Hv6gucBJNo',
#   'Label': {'objects': [{'featureId': 'cl9ezq0wf0010356l633t52ys',
#      'schemaId': 'cl9ddxges2pkh07yy5bbwf93y',
#      'color': '#1CE6FF',
#      'title': 'all',
#      'value': 'all',
#      'polygon': [{'x': 1889.445, 'y': 1735.295},
#       {'x': 2048, 'y': 2193.342},
#       {'x': 2558.899, 'y': 2457.6},
#       {'x': 2232.981, 'y': 2034.787}],
#      'instanceURI': 'https://api.labelbox.com/masks/feature/cl9ezq0wf0010356l633t52ys?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjbDk2MWM4a2kwcHh3MDgxN2h5MndlcmY0Iiwib3JnYW5pemF0aW9uSWQiOiJjbDk2MWM4azMwcHh2MDgxN2RxN3QwdmVoIiwiaWF0IjoxNjY2MTQ1MDU0LCJleHAiOjE2Njg3MzcwNTR9.eq5QfQmZarka--1AUZVFxoS3cBGRCfXa1Xn8RUdl2Aw'}],
#    'classifications': [],
#    'relationships': []},
#   'Created By': 'as15796@nyu.edu',
#   'Project Name': 'Tower Mapping Ale',
#   'Created At': '2022-10-19T02:03:43.000Z',
#   'Updated At': '2022-10-19T02:03:47.000Z',
#   'Seconds to Label': 7.831,
#   'Seconds to Review': 0,
#   'Seconds to Create': 7.831,
#   'External ID': '10015674326.png',
#   'Global Key': None,
#   'Agreement': -1,
#   'Benchmark Agreement': -1,
#   'Benchmark ID': None,
#   'Dataset Name': 'first images ale',
#   'Reviews': [],
#   'View Label': 'https://editor.labelbox.com?project=cl964zz4s1h9u07xvff7thgkk&label=cl9ezpxbh1udj07yr482le60a',
#   'Has Open Issues': 0,
#   'Skipped': False}]

# %%
tabular_bb
# Out:
#                  id     min_x     min_y     max_x     max_y
# 0    1550575138.png  1704.465   872.052  2215.363  2210.959
# 0    1608952103.png  1545.910   466.856  2224.172  2633.772
# 0    1668498831.png  1528.292  1101.075  2382.727  2202.151
# 0    1670739886.png  1880.637  1735.295  2338.684  2184.533
# 0    1670739890.png  2171.320  1197.970  3078.606  2175.725
# ..              ...       ...       ...       ...       ...
# 0    9807316522.png   207.002  1920.275   541.729  2351.897
# 0    9932900980.png   946.925  2175.725  1325.695  2572.112
# 0    9932900980.png  1933.488  1717.677  2215.363  2149.299
# 0    9934872453.png  1863.019  1805.763  2347.492  2246.194
# 0   10015674326.png  1889.445  1735.295  2558.899  2457.600
#
# [1112 rows x 5 columns]
